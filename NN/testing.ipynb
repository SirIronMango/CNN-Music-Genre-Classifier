# %%
# test_gpu.py
import torch

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
    print(f"GPU Count: {torch.cuda.device_count()}")
    
    # Test tensor on GPU
    x = torch.randn(3, 3).cuda()
    print(f"Tensor device: {x.device}")
    
    # Test GPU operations
    y = torch.randn(3, 3).cuda()
    z = x @ y  # Matrix multiplication on GPU
    print(f"GPU operation successful: {z.shape}")
else:
    print("No GPU detected. Check CUDA installation.")
# Out:
# PyTorch Version: 2.9.1+cu126
# CUDA Available: True
# GPU Device: NVIDIA GeForce GTX 1650
# GPU Count: 1
# Tensor device: cuda:0
# GPU operation successful: torch.Size([3, 3])

# %%
import torch
print(f"Is CUDA available? : {torch.cuda.is_available()}")
print(f"GPU Name           : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# Is CUDA available? : True
# GPU Name           : NVIDIA GeForce GTX 1650

# %%
import torch
import torchaudio
print(f"Torch: {torch.__version__}")
print(f"Audio: {torchaudio.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
# Out:
# Torch: 2.11.0.dev20260128+cu126
# Audio: 2.11.0.dev20260128+cu126
# CUDA: True
