# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore')


from google.colab import drive
drive.mount('/content/drive')


DATA_PATH = "/content/drive/MyDrive/data_tensors.pt"
BATCH_SIZE = 64
EPOCHS = 300
LEARNING_RATE = 0.001
PATIENCE = 20

torch.backends.cudnn.benchmark = True
torch.manual_seed(42)
np.random.seed(42)

class MFCC_CNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()

        # Block 1:
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ELU(alpha=1.0, inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ELU(alpha=1.0, inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(0.1)
        )

        # Block 2:
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ELU(alpha=1.0, inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ELU(alpha=1.0, inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(0.2)
        )

        # Block 3:
        self.conv3 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ELU(alpha=1.0, inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ELU(alpha=1.0, inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(0.3)
        )

        # Block 4:
        self.conv4 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ELU(alpha=1.0, inplace=True),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Dropout2d(0.4)
        )

        # Classifier
        self.fc = nn.Sequential(
            nn.Linear(512, 256),
            nn.ELU(alpha=1.0, inplace=True),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 128),
            nn.ELU(alpha=1.0, inplace=True),
            nn.BatchNorm1d(128),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)
            elif isinstance(m, nn.BatchNorm2d) or isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.constant_(m.bias, 0.1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

class DeadNeuronMonitor:
    def __init__(self, model, threshold=0.95):
        self.model = model
        self.threshold = threshold
        self.hooks = []
        self.activations = {}

    def _activation_hook(self, name):
        def hook(module, input, output):
            self.activations[name] = output.detach()
        return hook

    def attach_hooks(self):
        self.activations = {}
        for name, module in self.model.named_modules():
            if isinstance(module, (nn.Conv2d, nn.Linear, nn.ELU)):
                self.hooks.append(module.register_forward_hook(self._activation_hook(name)))

    def remove_hooks(self):
        for hook in self.hooks:
            hook.remove()
        self.hooks = []

    def check_dead_neurons(self, data, device):
        self.model.eval()
        self.attach_hooks()
        with torch.no_grad():
            _ = self.model(data.to(device))

        total_dead = 0
        total_neurons = 0
        for name, activation in self.activations.items():
            if isinstance(activation, torch.Tensor):
                if len(activation.shape) == 4:
                    batch, channels, h, w = activation.shape
                    activation = activation.view(batch, channels, -1)
                    inactive = (activation <= 0).float().mean(dim=2)
                    dead = (inactive > self.threshold).sum().item()
                    total_dead += dead
                    total_neurons += channels
                elif len(activation.shape) == 2:
                    batch, features = activation.shape
                    inactive = (activation <= 0).float().mean(dim=0)
                    dead = (inactive > self.threshold).sum().item()
                    total_dead += dead
                    total_neurons += features
        self.remove_hooks()
        return (total_dead / total_neurons) * 100 if total_neurons > 0 else 0.0

def train_model(model, train_data, val_data, epochs, device, patience=PATIENCE):
    X_train, y_train = train_data
    X_val, y_val = val_data

    train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X_train, y_train), batch_size=BATCH_SIZE, shuffle=True)
    val_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X_val, y_val), batch_size=BATCH_SIZE, shuffle=False)

    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=LEARNING_RATE * 0.01)
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    monitor = DeadNeuronMonitor(model)

    history = {'epoch': [], 'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': [], 'dead_train': [], 'dead_val': []}

    best_val_acc = 0
    epochs_no_improve = 0

    print(f"{'Epoch':<6} | {'Train Loss':<10} | {'Val Loss':<10} | {'Train Acc':<10} | {'Val Acc':<10} | {'Dead %':<10}")
    print("-" * 75)

    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0, 0, 0

        pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}', leave=False)
        for data, target in pbar:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            _, predicted = output.max(1)
            train_total += target.size(0)
            train_correct += predicted.eq(target).sum().item()
            train_loss += loss.item() * target.size(0)
            pbar.set_postfix({'Acc': 100.*train_correct/train_total})

        scheduler.step()
        train_loss /= len(X_train)
        train_acc = train_correct / train_total

        model.eval()
        val_loss, val_correct, val_total = 0, 0, 0
        with torch.no_grad():
            for data, target in val_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                loss = criterion(output, target)
                val_loss += loss.item() * target.size(0)
                _, predicted = output.max(1)
                val_total += target.size(0)
                val_correct += predicted.eq(target).sum().item()

        val_loss /= len(X_val)
        val_acc = val_correct / val_total

        sample_data, _ = next(iter(train_loader))
        dead_train = monitor.check_dead_neurons(sample_data[:32], device)

        history['epoch'].append(epoch + 1)
        history['train_loss'].append(train_loss); history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc); history['val_acc'].append(val_acc)
        history['dead_train'].append(dead_train)

        print(f"{epoch+1:<6} | {train_loss:<10.4f} | {val_loss:<10.4f} | {train_acc:<10.4f} | {val_acc:<10.4f} | {dead_train:<10.1f}")


        if val_acc > best_val_acc:
            best_val_acc = val_acc
            epochs_no_improve = 0
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'val_acc': val_acc,
                'history': history
            }, 'best_model.pth')
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"\nEarly stopping triggered after {patience} epochs without improvement.")
                break

    return model, history


def plot_results_table(history):
    print(f"{'Epoch':<6} | {'Train Loss':<12} | {'Val Loss':<12} | "
          f"{'Train Acc':<12} | {'Val Acc':<12} | {'Dead %':<12}")
    print("-" * 90)
    for i in range(0, len(history['epoch']), 10):
        if i < len(history['epoch']):
            idx = i
            print(f"{history['epoch'][idx]:<6} | {history['train_loss'][idx]:<12.4f} | {history['val_loss'][idx]:<12.4f} | "
                  f"{history['train_acc'][idx]:<12.4f} | {history['val_acc'][idx]:<12.4f} | {history['dead_train'][idx]:<12.1f}")
    if len(history['epoch']) > 0:
        idx = -1
        print("-" * 90)
        print(f"{history['epoch'][idx]:<6} | {history['train_loss'][idx]:<12.4f} | {history['val_loss'][idx]:<12.4f} | "
              f"{history['train_acc'][idx]:<12.4f} | {history['val_acc'][idx]:<12.4f} | {history['dead_train'][idx]:<12.1f}")

def plot_training_curves(history):
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    axes[0].plot(history['epoch'], history['train_acc'], label='Train')
    axes[0].plot(history['epoch'], history['val_acc'], label='Val')
    axes[0].axhline(y=0.96, color='r', linestyle='--', label='Target 96%')
    axes[0].set_title('Accuracy'); axes[0].legend(); axes[0].grid(True, alpha=0.3)
    axes[1].plot(history['epoch'], history['train_loss'], label='Train')
    axes[1].plot(history['epoch'], history['val_loss'], label='Val')
    axes[1].set_title('Loss'); axes[1].legend(); axes[1].grid(True, alpha=0.3)
    axes[2].plot(history['epoch'], history['dead_train'], label='Dead %')
    axes[2].set_title('Dead Neurons'); axes[2].grid(True, alpha=0.3)
    plt.tight_layout(); plt.show()

def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f" Using device: {device}")

    if not os.path.exists(DATA_PATH):
        print(f" Data not found at {DATA_PATH}"); return

    data = torch.load(DATA_PATH)
    X_train, y_train = data['X_train'], data['y_train']
    X_val, y_val = data['X_val'], data['y_val']

    mean = X_train.mean(dim=(0, 2, 3), keepdim=True)
    std = X_train.std(dim=(0, 2, 3), keepdim=True) + 1e-8
    X_train = torch.clamp((X_train - mean) / std, -3, 3)
    X_val = torch.clamp((X_val - mean) / std, -3, 3)

    model = MFCC_CNN(num_classes=len(torch.unique(y_train))).to(device)

    model, history = train_model(model, (X_train, y_train), (X_val, y_val), epochs=EPOCHS, device=device, patience=PATIENCE)

    plot_results_table(history)
    plot_training_curves(history)

    checkpoint = torch.load('best_model.pth')
    model.load_state_dict(checkpoint['model_state_dict'])

    model.eval()
    val_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X_val, y_val), batch_size=BATCH_SIZE)

    all_preds, all_targets = [], []
    with torch.no_grad():
        for data, target in val_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            all_preds.extend(output.argmax(1).cpu().numpy())
            all_targets.extend(target.cpu().numpy())

    final_acc = np.mean(np.array(all_preds) == np.array(all_targets))
    print(f"\nBest validation accuracy: {checkpoint['val_acc']:.4f}")
    print(f"Final validation accuracy (restored): {final_acc:.4f}")

    torch.save({'model_state_dict': model.state_dict(), 'history': history}, 'mfcc_model_final.pth')

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  Using device: cuda
# Epoch  | Train Loss | Val Loss   | Train Acc  | Val Acc    | Dead %
# ---------------------------------------------------------------------------
# Epoch 1:   0%|          | 0/110 [00:00<?, ?it/s]
# 1      | 2.1866     | 1.5570     | 0.3123     | 0.5215     | 56.6
# Epoch 2:   0%|          | 0/110 [00:00<?, ?it/s]
# 2      | 1.7211     | 1.4190     | 0.4589     | 0.5806     | 56.2
# Epoch 3:   0%|          | 0/110 [00:00<?, ?it/s]
# 3      | 1.5783     | 1.2976     | 0.5201     | 0.6537     | 93.4
# Epoch 4:   0%|          | 0/110 [00:00<?, ?it/s]
# 4      | 1.4815     | 1.2649     | 0.5567     | 0.6597     | 89.8
# Epoch 5:   0%|          | 0/110 [00:00<?, ?it/s]
# 5      | 1.4051     | 1.1975     | 0.6025     | 0.6847     | 81.0
# Epoch 6:   0%|          | 0/110 [00:00<?, ?it/s]
# 6      | 1.3509     | 1.1804     | 0.6288     | 0.7047     | 75.0
# Epoch 7:   0%|          | 0/110 [00:00<?, ?it/s]
# 7      | 1.2974     | 1.1720     | 0.6581     | 0.6897     | 76.3
# Epoch 8:   0%|          | 0/110 [00:00<?, ?it/s]
# 8      | 1.2665     | 1.1105     | 0.6644     | 0.7367     | 75.7
# Epoch 9:   0%|          | 0/110 [00:00<?, ?it/s]
# 9      | 1.2395     | 1.0672     | 0.6827     | 0.7508     | 73.3
# Epoch 10:   0%|          | 0/110 [00:00<?, ?it/s]
# 10     | 1.1957     | 1.0291     | 0.7020     | 0.7668     | 71.1
# Epoch 11:   0%|          | 0/110 [00:00<?, ?it/s]
# 11     | 1.1808     | 1.0007     | 0.7068     | 0.7858     | 59.8
# Epoch 12:   0%|          | 0/110 [00:00<?, ?it/s]
# 12     | 1.1499     | 0.9941     | 0.7223     | 0.7858     | 67.2
# Epoch 13:   0%|          | 0/110 [00:00<?, ?it/s]
# 13     | 1.1351     | 0.9986     | 0.7290     | 0.7898     | 76.5
# Epoch 14:   0%|          | 0/110 [00:00<?, ?it/s]
# 14     | 1.1129     | 0.9884     | 0.7425     | 0.7918     | 53.8
# Epoch 15:   0%|          | 0/110 [00:00<?, ?it/s]
# 15     | 1.0816     | 0.9490     | 0.7579     | 0.8018     | 54.1
# Epoch 16:   0%|          | 0/110 [00:00<?, ?it/s]
# 16     | 1.0553     | 0.9333     | 0.7678     | 0.8208     | 66.2
# Epoch 17:   0%|          | 0/110 [00:00<?, ?it/s]
# 17     | 1.0517     | 0.9620     | 0.7676     | 0.8098     | 47.5
# Epoch 18:   0%|          | 0/110 [00:00<?, ?it/s]
# 18     | 1.0164     | 0.9380     | 0.7875     | 0.8048     | 69.2
# Epoch 19:   0%|          | 0/110 [00:00<?, ?it/s]
# 19     | 1.0039     | 0.9256     | 0.7951     | 0.8168     | 59.7
# Epoch 20:   0%|          | 0/110 [00:00<?, ?it/s]
# 20     | 0.9860     | 0.8882     | 0.8032     | 0.8438     | 66.3
# Epoch 21:   0%|          | 0/110 [00:00<?, ?it/s]
# 21     | 0.9699     | 0.8706     | 0.8072     | 0.8519     | 46.9
# Epoch 22:   0%|          | 0/110 [00:00<?, ?it/s]
# 22     | 0.9424     | 0.8998     | 0.8230     | 0.8278     | 50.9
# Epoch 23:   0%|          | 0/110 [00:00<?, ?it/s]
# 23     | 0.9335     | 0.8587     | 0.8233     | 0.8549     | 44.1
# Epoch 24:   0%|          | 0/110 [00:00<?, ?it/s]
# 24     | 0.9164     | 0.8359     | 0.8321     | 0.8679     | 54.8
# Epoch 25:   0%|          | 0/110 [00:00<?, ?it/s]
# 25     | 0.9106     | 0.8474     | 0.8338     | 0.8659     | 47.9
# Epoch 26:   0%|          | 0/110 [00:00<?, ?it/s]
# 26     | 0.8915     | 0.8134     | 0.8471     | 0.8779     | 44.8
# Epoch 27:   0%|          | 0/110 [00:00<?, ?it/s]
# 27     | 0.8762     | 0.8265     | 0.8523     | 0.8679     | 43.5
# Epoch 28:   0%|          | 0/110 [00:00<?, ?it/s]
# 28     | 0.8645     | 0.8102     | 0.8550     | 0.8789     | 49.0
# Epoch 29:   0%|          | 0/110 [00:00<?, ?it/s]
# 29     | 0.8578     | 0.8221     | 0.8636     | 0.8589     | 53.8
# Epoch 30:   0%|          | 0/110 [00:00<?, ?it/s]
# 30     | 0.8356     | 0.8255     | 0.8694     | 0.8689     | 36.1
# Epoch 31:   0%|          | 0/110 [00:00<?, ?it/s]
# 31     | 0.8239     | 0.8371     | 0.8783     | 0.8539     | 44.7
# Epoch 32:   0%|          | 0/110 [00:00<?, ?it/s]
# 32     | 0.8135     | 0.7906     | 0.8780     | 0.8859     | 25.9
# Epoch 33:   0%|          | 0/110 [00:00<?, ?it/s]
# 33     | 0.7910     | 0.8197     | 0.8905     | 0.8809     | 35.5
# Epoch 34:   0%|          | 0/110 [00:00<?, ?it/s]
# 34     | 0.7880     | 0.7784     | 0.8932     | 0.8949     | 30.4
# Epoch 35:   0%|          | 0/110 [00:00<?, ?it/s]
# 35     | 0.7717     | 0.7965     | 0.8993     | 0.8859     | 26.8
# Epoch 36:   0%|          | 0/110 [00:00<?, ?it/s]
# 36     | 0.7615     | 0.7902     | 0.9005     | 0.8839     | 33.4
# Epoch 37:   0%|          | 0/110 [00:00<?, ?it/s]
# 37     | 0.7641     | 0.7899     | 0.8995     | 0.8809     | 26.5
# Epoch 38:   0%|          | 0/110 [00:00<?, ?it/s]
# 38     | 0.7463     | 0.8216     | 0.9128     | 0.8689     | 18.3
# Epoch 39:   0%|          | 0/110 [00:00<?, ?it/s]
# 39     | 0.7328     | 0.7571     | 0.9162     | 0.9029     | 29.1
# Epoch 40:   0%|          | 0/110 [00:00<?, ?it/s]
# 40     | 0.7295     | 0.7523     | 0.9159     | 0.9049     | 24.0
# Epoch 41:   0%|          | 0/110 [00:00<?, ?it/s]
# 41     | 0.7155     | 0.7622     | 0.9236     | 0.8959     | 40.2
# Epoch 42:   0%|          | 0/110 [00:00<?, ?it/s]
# 42     | 0.7117     | 0.7745     | 0.9248     | 0.8889     | 23.3
# Epoch 43:   0%|          | 0/110 [00:00<?, ?it/s]
# 43     | 0.6950     | 0.7270     | 0.9331     | 0.9029     | 19.1
# Epoch 44:   0%|          | 0/110 [00:00<?, ?it/s]
# 44     | 0.6958     | 0.7362     | 0.9314     | 0.9049     | 30.9
# Epoch 45:   0%|          | 0/110 [00:00<?, ?it/s]
# 45     | 0.6802     | 0.7516     | 0.9398     | 0.8969     | 26.3
# Epoch 46:   0%|          | 0/110 [00:00<?, ?it/s]
# 46     | 0.6842     | 0.7704     | 0.9368     | 0.8849     | 17.1
# Epoch 47:   0%|          | 0/110 [00:00<?, ?it/s]
# 47     | 0.6781     | 0.7589     | 0.9419     | 0.8999     | 18.7
# Epoch 48:   0%|          | 0/110 [00:00<?, ?it/s]
# 48     | 0.6680     | 0.7348     | 0.9461     | 0.9039     | 17.9
# Epoch 49:   0%|          | 0/110 [00:00<?, ?it/s]
# 49     | 0.6582     | 0.7370     | 0.9515     | 0.9049     | 21.9
# Epoch 50:   0%|          | 0/110 [00:00<?, ?it/s]
# 50     | 0.6580     | 0.7241     | 0.9482     | 0.9119     | 20.1
# Epoch 51:   0%|          | 0/110 [00:00<?, ?it/s]
# 51     | 0.6509     | 0.7091     | 0.9531     | 0.9229     | 20.5
# Epoch 52:   0%|          | 0/110 [00:00<?, ?it/s]
# 52     | 0.6427     | 0.7382     | 0.9538     | 0.9019     | 21.5
# Epoch 53:   0%|          | 0/110 [00:00<?, ?it/s]
# 53     | 0.6411     | 0.7383     | 0.9542     | 0.8969     | 18.7
# Epoch 54:   0%|          | 0/110 [00:00<?, ?it/s]
# 54     | 0.6445     | 0.7457     | 0.9542     | 0.9009     | 28.7
# Epoch 55:   0%|          | 0/110 [00:00<?, ?it/s]
# 55     | 0.6328     | 0.7210     | 0.9611     | 0.9049     | 16.9
# Epoch 56:   0%|          | 0/110 [00:00<?, ?it/s]
# 56     | 0.6326     | 0.7274     | 0.9601     | 0.9029     | 24.5
# Epoch 57:   0%|          | 0/110 [00:00<?, ?it/s]
# 57     | 0.6284     | 0.7236     | 0.9601     | 0.9149     | 18.7
# Epoch 58:   0%|          | 0/110 [00:00<?, ?it/s]
# 58     | 0.6146     | 0.7566     | 0.9687     | 0.8999     | 22.1
# Epoch 59:   0%|          | 0/110 [00:00<?, ?it/s]
# 59     | 0.6214     | 0.7262     | 0.9648     | 0.9119     | 18.2
# Epoch 60:   0%|          | 0/110 [00:00<?, ?it/s]
# 60     | 0.6145     | 0.7001     | 0.9645     | 0.9139     | 22.7
# Epoch 61:   0%|          | 0/110 [00:00<?, ?it/s]
# 61     | 0.6184     | 0.7247     | 0.9630     | 0.9079     | 14.9
# Epoch 62:   0%|          | 0/110 [00:00<?, ?it/s]
# 62     | 0.6094     | 0.7102     | 0.9698     | 0.9199     | 12.3
# Epoch 63:   0%|          | 0/110 [00:00<?, ?it/s]
# 63     | 0.6089     | 0.7195     | 0.9701     | 0.9079     | 19.1
# Epoch 64:   0%|          | 0/110 [00:00<?, ?it/s]
# 64     | 0.6002     | 0.7058     | 0.9743     | 0.9139     | 18.6
# Epoch 65:   0%|          | 0/110 [00:00<?, ?it/s]
# 65     | 0.6051     | 0.7455     | 0.9708     | 0.9069     | 20.3
# Epoch 66:   0%|          | 0/110 [00:00<?, ?it/s]
# 66     | 0.5962     | 0.7061     | 0.9744     | 0.9199     | 22.1
# Epoch 67:   0%|          | 0/110 [00:00<?, ?it/s]
# 67     | 0.5961     | 0.7146     | 0.9743     | 0.9139     | 26.1
# Epoch 68:   0%|          | 0/110 [00:00<?, ?it/s]
# 68     | 0.5965     | 0.7164     | 0.9741     | 0.9079     | 20.7
# Epoch 69:   0%|          | 0/110 [00:00<?, ?it/s]
# 69     | 0.5945     | 0.7047     | 0.9747     | 0.9159     | 16.9
# Epoch 70:   0%|          | 0/110 [00:00<?, ?it/s]
# 70     | 0.5899     | 0.7280     | 0.9768     | 0.9079     | 25.3
# Epoch 71:   0%|          | 0/110 [00:00<?, ?it/s]
# 71     | 0.5953     | 0.7277     | 0.9743     | 0.9129     | 22.4
#
# Early stopping triggered after 20 epochs without improvement.
# Epoch  | Train Loss   | Val Loss     | Train Acc    | Val Acc      | Dead %
# ------------------------------------------------------------------------------------------
# 1      | 2.1866       | 1.5570       | 0.3123       | 0.5215       | 56.6
# 11     | 1.1808       | 1.0007       | 0.7068       | 0.7858       | 59.8
# 21     | 0.9699       | 0.8706       | 0.8072       | 0.8519       | 46.9
# 31     | 0.8239       | 0.8371       | 0.8783       | 0.8539       | 44.7
# 41     | 0.7155       | 0.7622       | 0.9236       | 0.8959       | 40.2
# 51     | 0.6509       | 0.7091       | 0.9531       | 0.9229       | 20.5
# 61     | 0.6184       | 0.7247       | 0.9630       | 0.9079       | 14.9
# 71     | 0.5953       | 0.7277       | 0.9743       | 0.9129       | 22.4
# ------------------------------------------------------------------------------------------
# 71     | 0.5953       | 0.7277       | 0.9743       | 0.9129       | 22.4
# Best validation accuracy: 0.9229
# Final validation accuracy (restored): 0.9229
